# %%
import openai

# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
import os

# %%
response = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[{"role": "user", "content":"Is it too late to join the course?"}]
)

# %%
response.choices[0].message.content
# Out:
# "Whether it's too late to join a course depends on the specific course you are interested in and its enrollment policies. Many courses have set deadlines for registration, while some may allow late enrollment or have rolling admissions. It would be best to check the course's official website or contact the instructor or administration directly for the most accurate information. If you provide more details about the course, I may be able to give more tailored advice."
